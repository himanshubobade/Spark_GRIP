# %% [markdown]
# # ML Application

# %%
import time
import datetime
from datetime import date
import requests
from io import StringIO
import csv
import pandas as pd
import numpy as np

# %%
datetime.datetime.fromtimestamp(1622937600)
# Out:
# datetime.datetime(2021, 6, 6, 5, 30)

# %%
datetime.datetime(2021,6,8,5,30).timestamp()
# Out:
# 1623110400.0

# %%
current_time = datetime.datetime.now()
current_time.year
# Out:
# 2021

# %%
'''
if current_time.hour >5:
    epoch = str(int(datetime.datetime(current_time.year,current_time.month,current_time.day,5,30).timestamp()))
    #print(epoch)
    
elif current_time.hour==5 and current_time.minute >=30 :
    epoch = str(int(datetime.datetime(current_time.year,current_time.month,current_time.day,5,30).timestamp()))
    #print(epoch)
else:
'''
epoch = str(int(datetime.datetime(current_time.year,current_time.month,current_time.day,5,30).timestamp()))
#print(epoch)

# %%
print(epoch)
# Out:
# 1623369600

# %%
#url = f"https://query1.finance.yahoo.com/v7/finance/download/%5ENSEI?period1=1465344000&period2={epoch}&interval=1d&events=history&includeAdjustedClose=true"
#print(url)
#url=f"https://query1.finance.yahoo.com/v7/finance/download/MSFT?period1=1465603200&period2={epoch}&interval=1d&events=history&includeAdjustedClose=true"
url = "https://query1.finance.yahoo.com/v7/finance/download/MSFT?period1=1218153600&period2=1467331200&interval=1d&events=history&includeAdjustedClose=true"
print(url)
# Out:
# https://query1.finance.yahoo.com/v7/finance/download/MSFT?period1=1218153600&period2=1467331200&interval=1d&events=history&includeAdjustedClose=true

# %%
data = pd.read_csv(url)
date2 = data
print(data)
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2008-08-08  27.350000  28.230000  27.190001  28.129999  21.081116
# 1     2008-08-11  27.860001  28.400000  27.660000  27.900000  20.908747
# 2     2008-08-12  27.780001  28.360001  27.580000  28.120001  21.073622
# 3     2008-08-13  28.070000  28.500000  27.760000  27.910000  20.916243
# 4     2008-08-14  27.820000  28.280001  27.559999  27.910000  20.916243
# ...          ...        ...        ...        ...        ...        ...
# 1983  2016-06-24  49.810001  50.939999  49.520000  49.830002  45.906292
# 1984  2016-06-27  49.099998  49.150002  48.040001  48.430000  44.616528
# 1985  2016-06-28  48.919998  49.470001  48.669998  49.439999  45.546997
# 1986  2016-06-29  49.910000  50.720001  49.799999  50.540001  46.560383
# 1987  2016-06-30  50.720001  51.299999  50.500000  51.169998  47.140781
#
#          Volume
# 0      80814100
# 1      68743800
# 2      62813000
# 3      51165200
# ...

# %%
data.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2008-08-08  27.350000  28.230000  27.190001  28.129999  21.081116  80814100
# 1  2008-08-11  27.860001  28.400000  27.660000  27.900000  20.908747  68743800
# 2  2008-08-12  27.780001  28.360001  27.580000  28.120001  21.073622  62813000
# 3  2008-08-13  28.070000  28.500000  27.760000  27.910000  20.916243  51165200
# 4  2008-08-14  27.820000  28.280001  27.559999  27.910000  20.916243  49732300

# %%
data
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2008-08-08  27.350000  28.230000  27.190001  28.129999  21.081116
# 1     2008-08-11  27.860001  28.400000  27.660000  27.900000  20.908747
# 2     2008-08-12  27.780001  28.360001  27.580000  28.120001  21.073622
# 3     2008-08-13  28.070000  28.500000  27.760000  27.910000  20.916243
# 4     2008-08-14  27.820000  28.280001  27.559999  27.910000  20.916243
# ...          ...        ...        ...        ...        ...        ...
# 1983  2016-06-24  49.810001  50.939999  49.520000  49.830002  45.906292
# 1984  2016-06-27  49.099998  49.150002  48.040001  48.430000  44.616528
# 1985  2016-06-28  48.919998  49.470001  48.669998  49.439999  45.546997
# 1986  2016-06-29  49.910000  50.720001  49.799999  50.540001  46.560383
# 1987  2016-06-30  50.720001  51.299999  50.500000  51.169998  47.140781
#
#          Volume
# 0      80814100
# 1      68743800
# 2      62813000
# 3      51165200
# ...

# %%
data.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1988.000000  1988.000000  1988.000000  1988.000000  1988.000000
# mean     33.264024    33.594105    32.939965    33.281685    28.058357
# std       9.864698     9.926521     9.813740     9.881030    10.006580
# min      15.200000    15.620000    14.870000    15.150000    11.554865
# 25%      25.947501    26.200001    25.660000    25.940001    20.547163
# 50%      29.840000    30.049999    29.610001    29.850000    24.112710
# 75%      41.452500    41.830002    41.152501    41.552499    36.502481
# max      56.630001    56.849998    56.290001    56.549999    51.652946
#
#              Volume
# count  1.988000e+03
# mean   5.139078e+07
# std    2.765574e+07
# min    9.009100e+06
# 25%    3.343562e+07
# 50%    4.613480e+07
# 75%    6.162462e+07
# max    3.193179e+08

# %%
data.rename(columns = {'Adj Close' : 'Adj_Close'}, inplace = True)
data.describe()
data['Open'] = data['Open'].fillna(0)
data['High'] = data['High'].fillna(0)
data['Low'] = data['Low'].fillna(0)
data['Close'] = data['Close'].fillna(0)
data['Adj_Close'] = data['Adj_Close'].fillna(0)
data['Volume'] = data['Volume'].fillna(0)

# %%
data.describe()
# Out:
#               Open         High          Low        Close    Adj_Close  \
# count  1988.000000  1988.000000  1988.000000  1988.000000  1988.000000
# mean     33.264024    33.594105    32.939965    33.281685    28.058357
# std       9.864698     9.926521     9.813740     9.881030    10.006580
# min      15.200000    15.620000    14.870000    15.150000    11.554865
# 25%      25.947501    26.200001    25.660000    25.940001    20.547163
# 50%      29.840000    30.049999    29.610001    29.850000    24.112710
# 75%      41.452500    41.830002    41.152501    41.552499    36.502481
# max      56.630001    56.849998    56.290001    56.549999    51.652946
#
#              Volume
# count  1.988000e+03
# mean   5.139078e+07
# std    2.765574e+07
# min    9.009100e+06
# 25%    3.343562e+07
# 50%    4.613480e+07
# 75%    6.162462e+07
# max    3.193179e+08

# %%
data.Open = data.Open.fillna(data.Open.median())
data.High = data.High.fillna(data.High.median())
data.Low = data.Low.fillna(data.Low.median())
data.Close = data.Close.fillna(data.Close.median())
data.Adj_Close = data.Adj_Close.fillna(data.Adj_Close.median())
data.Volume = data.Volume.fillna(data.Volume.median())
'''
data.Open = data.Open.fillna(data.Open.mean())
data.High = data.High.fillna(data.High.mean())
data.Low = data.Low.fillna(data.Low.mean())
data.Close = data.Close.fillna(data.Close.mean())
data.Adj_Close = data.Adj_Close.fillna(data.Adj_Close.mean())
data.Volume = data.Volume.fillna(data.Volume.mean())
'''
# Out:
# '\ndata.Open = data.Open.fillna(data.Open.mean())\ndata.High = data.High.fillna(data.High.mean())\ndata.Low = data.Low.fillna(data.Low.mean())\ndata.Close = data.Close.fillna(data.Close.mean())\ndata.Adj_Close = data.Adj_Close.fillna(data.Adj_Close.mean())\ndata.Volume = data.Volume.fillna(data.Volume.mean())\n'

# %%
data[450:500]
# Out:
#            Date       Open       High        Low      Close  Adj_Close  \
# 450  2010-05-24  26.850000  26.860001  26.260000  26.270000  20.553869
# 451  2010-05-25  25.650000  26.330000  25.379999  26.070000  20.397394
# 452  2010-05-26  26.230000  26.610001  24.559999  25.010000  19.568035
# 453  2010-05-27  25.730000  26.360001  25.730000  26.000000  20.342628
# 454  2010-05-28  25.840000  26.120001  25.660000  25.799999  20.186144
# 455  2010-06-01  25.530001  26.309999  25.520000  25.889999  20.256563
# 456  2010-06-02  26.059999  26.480000  25.730000  26.459999  20.702532
# 457  2010-06-03  26.549999  26.930000  26.410000  26.860001  21.015499
# 458  2010-06-04  26.100000  26.570000  25.620001  25.790001  20.178326
# 459  2010-06-07  25.820000  25.830000  25.240000  25.290001  19.787119
# 460  2010-06-08  25.250000  25.260000  24.650000  25.110001  19.646280
# 461  2010-06-09  25.219999  25.520000  24.750000  24.790001  19.395908
# ...

# %%
'''
nonzero_mean = data[ data.High != 0 ].mean()
data.loc[data.High == 0,"High"] = nonzero_mean

nonzero_mean = data[ data.Low != 0 ].mean()
data.loc[data.Low == 0,"Low"] = nonzero_mean

nonzero_mean = data[ data.Close != 0 ].mean()
data.loc[data.Close == 0,"Close"] = nonzero_mean

nonzero_mean = data[ data.Volume != 0 ].mean()
data.loc[data.Volume == 0,"Volume"] = nonzero_mean
'''
# Out:
# '\nnonzero_mean = data[ data.High != 0 ].mean()\ndata.loc[data.High == 0,"High"] = nonzero_mean\n\nnonzero_mean = data[ data.Low != 0 ].mean()\ndata.loc[data.Low == 0,"Low"] = nonzero_mean\n\nnonzero_mean = data[ data.Close != 0 ].mean()\ndata.loc[data.Close == 0,"Close"] = nonzero_mean\n\nnonzero_mean = data[ data.Volume != 0 ].mean()\ndata.loc[data.Volume == 0,"Volume"] = nonzero_mean\n'

# %%
data.describe()
# Out:
#               Open         High          Low        Close    Adj_Close  \
# count  1988.000000  1988.000000  1988.000000  1988.000000  1988.000000
# mean     33.264024    33.594105    32.939965    33.281685    28.058357
# std       9.864698     9.926521     9.813740     9.881030    10.006580
# min      15.200000    15.620000    14.870000    15.150000    11.554865
# 25%      25.947501    26.200001    25.660000    25.940001    20.547163
# 50%      29.840000    30.049999    29.610001    29.850000    24.112710
# 75%      41.452500    41.830002    41.152501    41.552499    36.502481
# max      56.630001    56.849998    56.290001    56.549999    51.652946
#
#              Volume
# count  1.988000e+03
# mean   5.139078e+07
# std    2.765574e+07
# min    9.009100e+06
# 25%    3.343562e+07
# 50%    4.613480e+07
# 75%    6.162462e+07
# max    3.193179e+08

# %%
'''
print(np.percentile(data.Volume,[2])[0])
lv =  np.percentile(data.Volume,[2])[0]
data[(data.Volume<lv)]
data.Volume[(data.Volume<0.3*lv)] = 0.3*lv
data.describe()
'''
#x = data.Volume[data.Volume<(np.percentile(data.Volume,[1])[0])]
#print(data.Volume<(np.percentile(data.Volume,[1])[0]))
print(np.percentile(data.Volume,[1.8])[0])
print(data.Volume)
for i in range(len(data.Volume)):
    if (data.Volume)[i]<=np.percentile(data.Volume,[1.8])[0]:
        print((data.Volume)[i])
        data.Volume[i] = data.Volume[i-1]
        
    if (data.Open)[i]<=np.percentile(data.Open,[1.8])[0]:
        print((data.Open)[i])
        data.Open[i] = data.Open[i-1]
        
    if (data.High)[i]<=np.percentile(data.High,[1.8])[0]:
        print((data.High)[i])
        data.High[i] = data.High[i-1]
        
    if (data.Low)[i]<=np.percentile(data.Low,[1.8])[0]:
        print((data.Low)[i])
        data.Low[i] = data.Low[i-1]
        
    if (data.Close)[i]<=np.percentile(data.Close,[1.8])[0]:
        print((data.Close)[i])
        data.Close[i] = data.Close[i-1]
        
    if (data.Adj_Close)[i]<=np.percentile(data.Adj_Close,[1.8])[0]:
        print((data.Adj_Close)[i])
        data.Adj_Close[i] = data.Adj_Close[i-1]
# Out:
# 19210568.6
# 0        80814100
# 1        68743800
# 2        62813000
# 3        51165200
# 4        49732300
#           ...
# 1983    133503000
# 1984     50216300
# 1985     38140700
# 1986     31304000
# 1987     28527800
# Name: Volume, Length: 1988, dtype: int64
# 17.5
# 17.530001000000002
# 13.279036999999999
# 18.02
# 16880400
# 18.049999
# 18.18
# 17.07
# 17.110001
# 12.960891
# 16.969998999999998
# 17.49
# 16.75
# 17.200001
# 13.029058000000001
# 17.290001
# 17.809998999999998
# 17.23
# 17.629998999999998
# 13.354784
# 17.780001000000002
# 17.969998999999998
# 17.43
# 17.66
# 13.377510000000001
# 17.799999
# 18.309998999999998
# 17.76
# 18.040001
# 13.665366
# 17.780001000000002
# 17.959999
# 17.559998999999998
# 17.59
# 13.324489000000002
# 17.74
# 17.790001
# 17.1
# 17.1
# 12.953313
# 17.030001000000002
# 18.129998999999998
# 17.0
# 17.83
# 13.506292000000002
# 17.85
# 18.610001
# 17.6
# 18.5
# 14.013815
# 18.540001
# 19.0
# 18.629998999999998
# 14.112289
# 18.51
# ...

# %%
data[:60]
# Out:
#           Date       Open       High        Low      Close  Adj_Close  \
# 0   2008-08-08  27.350000  28.230000  27.190001  28.129999  21.081116
# 1   2008-08-11  27.860001  28.400000  27.660000  27.900000  20.908747
# 2   2008-08-12  27.780001  28.360001  27.580000  28.120001  21.073622
# 3   2008-08-13  28.070000  28.500000  27.760000  27.910000  20.916243
# 4   2008-08-14  27.820000  28.280001  27.559999  27.910000  20.916243
# 5   2008-08-15  27.980000  28.150000  27.580000  27.809999  20.841301
# 6   2008-08-18  27.780001  28.049999  27.549999  27.690001  20.751369
# 7   2008-08-19  27.540001  27.750000  27.270000  27.320000  20.555754
# 8   2008-08-20  27.540001  27.580000  27.170000  27.290001  20.533173
# 9   2008-08-21  27.100000  27.230000  26.860001  27.180000  20.450407
# 10  2008-08-22  27.230000  27.879999  27.219999  27.840000  20.946999
# 11  2008-08-25  27.610001  27.840000  27.459999  27.660000  20.811567
# ...

# %%
'''
nonzero_mean = data[ data.Adj_Close != 0 ].mean()
data.loc[data.Adj_Close == 0,"Adj_Close"] = nonzero_mean
data.describe()
'''
# Out:
# '\nnonzero_mean = data[ data.Adj_Close != 0 ].mean()\ndata.loc[data.Adj_Close == 0,"Adj_Close"] = nonzero_mean\ndata.describe()\n'

# %%
df1=data.reset_index()['Close']
df1[:60]
# Out:
# 0     28.129999
# 1     27.900000
# 2     28.120001
# 3     27.910000
# 4     27.910000
# 5     27.809999
# 6     27.690001
# 7     27.320000
# 8     27.290001
# 9     27.180000
# 10    27.840000
# 11    27.660000
# 12    27.270000
# 13    27.559999
# 14    27.940001
# 15    27.290001
# 16    27.100000
# 17    26.900000
# 18    26.350000
# 19    25.650000
# 20    26.120001
# 21    26.100000
# 22    26.440001
# 23    27.340000
# 24    27.620001
# 25    26.820000
# 26    25.990000
# 27    24.570000
# 28    25.260000
# 29    25.160000
# 30    25.400000
# 31    25.440001
# 32    25.719999
# 33    26.610001
# 34    27.400000
# 35    25.010000
# 36    26.690001
# 37    26.480000
# 38    26.250000
# 39    26.320000
# 40    24.910000
# 41    23.230000
# 42    23.010000
# 43    22.299999
# 44    21.500000
# 45    25.500000
# 46    24.100000
# 47    22.660000
# 48    24.190001
# 49    23.930000
# 50    24.719999
# 51    23.360001
# 52    21.530001
# 53    22.320000
# 54    21.959999
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(df1)

# %%
from pandas_datareader import data
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
import urllib.request, json
import os
import numpy as np
import tensorflow as tf # This code has been tested with TensorFlow 1.6
from sklearn.preprocessing import MinMaxScaler

# %%
df1.shape
# Out:
# (1988,)

# %%
scaler = MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
df1.shape
# Out:
# (1988, 1)

# %%
df1[:60]
# Out:
# array([[0.25718762],
#        [0.25117615],
#        [0.25692631],
#        [0.25143752],
#        [0.25143752],
#        [0.2488238 ],
#        [0.24568741],
#        [0.23601671],
#        [0.23523263],
#        [0.23235754],
#        [0.24960793],
#        [0.24490328],
#        [0.23470987],
#        [0.24228956],
#        [0.25222165],
#        [0.23523263],
#        [0.23026658],
#        [0.22503919],
#        [0.21066386],
#        [0.19236799],
#        [0.20465239],
#        [0.20412962],
#        [0.21301622],
#        [0.23653945],
#        [0.24385783],
#        [0.22294823],
#        [0.20125456],
#        [0.16414008],
#        [0.18217458],
#        [0.17956088],
#        [0.18583375],
#        [0.18687926],
#        [0.19419755],
#        [0.2174595 ],
#        [0.23810767],
#        [0.17564034],
#        [0.21955046],
#        [0.21406167],
#        [0.20805017],
#        [0.20987975],
#        [0.17302664],
#        [0.12911655],
#        [0.12336642],
# ...

# %%
training_size=int(len(df1)*0.65)
test_size=len(df1)-training_size
train_data,test_data=df1[0:training_size,:],df1[training_size:len(df1),:1]

# %%
training_size,test_size
# Out:
# (1292, 696)

# %%
len(train_data),len(test_data)
# Out:
# (1292, 696)

# %%
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train)
# Out:
# [[0.25718762 0.25117615 0.25692631 ... 0.02195499 0.01751171 0.02744378]
#  [0.25117615 0.25692631 0.25143752 ... 0.01751171 0.02744378 0.0300575 ]
#  [0.25692631 0.25143752 0.25143752 ... 0.02744378 0.0300575  0.05331937]
#  ...
#  [0.38708828 0.37715632 0.38865655 ... 0.38264505 0.39283847 0.40120227]
#  [0.37715632 0.38865655 0.3972818  ... 0.39283847 0.40120227 0.37898591]
#  [0.38865655 0.3972818  0.40407736 ... 0.40120227 0.37898591 0.37767908]]

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (1191, 100)
# (1191,)
# (None, None)

# %%
print(X_test.shape), print(ytest.shape)
# Out:
# (595, 100)
# (595,)
# (None, None)

# %%
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
X_train[1]
# Out:
# array([[0.25117615],
#        [0.25692631],
#        [0.25143752],
#        [0.25143752],
#        [0.2488238 ],
#        [0.24568741],
#        [0.23601671],
#        [0.23523263],
#        [0.23235754],
#        [0.24960793],
#        [0.24490328],
#        [0.23470987],
#        [0.24228956],
#        [0.25222165],
#        [0.23523263],
#        [0.23026658],
#        [0.22503919],
#        [0.21066386],
#        [0.19236799],
#        [0.20465239],
#        [0.20412962],
#        [0.21301622],
#        [0.23653945],
#        [0.24385783],
#        [0.22294823],
#        [0.20125456],
#        [0.16414008],
#        [0.18217458],
#        [0.17956088],
#        [0.18583375],
#        [0.18687926],
#        [0.19419755],
#        [0.2174595 ],
#        [0.23810767],
#        [0.17564034],
#        [0.21955046],
#        [0.21406167],
#        [0.20805017],
#        [0.20987975],
#        [0.17302664],
#        [0.12911655],
#        [0.12336642],
#        [0.10480915],
# ...

# %%
### Create the Stacked LSTM model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(units=50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(units=50,return_sequences=True))
model.add(LSTM(units=50))
model.add(Dense(units=1))
model.compile(optimizer='adam',loss='mean_squared_error')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm (LSTM)                  (None, 100, 50)           10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100, 50)           20200
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# ...
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm (LSTM)                  (None, 100, 50)           10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100, 50)           20200
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# ...
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_train
# Out:
# array([[[0.25718762],
#         [0.25117615],
#         [0.25692631],
#         ...,
#         [0.02195499],
#         [0.01751171],
#         [0.02744378]],
#
#        [[0.25117615],
#         [0.25692631],
#         [0.25143752],
#         ...,
#         [0.01751171],
#         [0.02744378],
#         [0.0300575 ]],
#
#        [[0.25692631],
#         [0.25143752],
#         [0.25143752],
#         ...,
#         [0.02744378],
#         [0.0300575 ],
#         [0.05331937]],
#
#        ...,
#
#        [[0.38708828],
#         [0.37715632],
#         [0.38865655],
#         ...,
#         [0.38264505],
#         [0.39283847],
#         [0.40120227]],
#
#        [[0.37715632],
#         [0.38865655],
#         [0.3972818 ],
#         ...,
#         [0.39283847],
#         [0.40120227],
#         [0.37898591]],
#
#        [[0.38865655],
#         [0.3972818 ],
#         [0.40407736],
#         ...,
#         [0.40120227],
#         [0.37898591],
#         [0.37767908]]])

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 19/19 [==============================] - 11s 275ms/step - loss: 0.0216 - val_loss: 0.0244
# Epoch 2/100
# 19/19 [==============================] - 2s 107ms/step - loss: 0.0023 - val_loss: 0.0093
# Epoch 3/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0011 - val_loss: 0.0027
# Epoch 4/100
# 19/19 [==============================] - 3s 136ms/step - loss: 8.2690e-04 - val_loss: 0.0032
# Epoch 5/100
# 19/19 [==============================] - 3s 144ms/step - loss: 7.7218e-04 - val_loss: 0.0046
# Epoch 6/100
# 19/19 [==============================] - 3s 160ms/step - loss: 7.9839e-04 - val_loss: 0.0028
# Epoch 7/100
# 19/19 [==============================] - 3s 158ms/step - loss: 7.3598e-04 - val_loss: 0.0053
# Epoch 8/100
# 19/19 [==============================] - 2s 113ms/step - loss: 7.3944e-04 - val_loss: 0.0032
# Epoch 9/100
# 19/19 [==============================] - 2s 124ms/step - loss: 6.9405e-04 - val_loss: 0.0041
# Epoch 10/100
# ...

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.4.1'

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# %%
##Transformback to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
len(train_predict),len(test_predict),len(y_train),len(ytest)
# Out:
# (1191, 595, 1191, 595)

# %%
train_predict
# Out:
# array([[19.36604 ],
#        [19.441465],
#        [19.71957 ],
#        ...,
#        [33.2383  ],
#        [32.722294],
#        [32.39318 ]], dtype=float32)

# %%
### Calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 27.16767377732832

# %%
### Test Data RMSE
math.sqrt(mean_squared_error(ytest,test_predict))
# Out:
# 44.610579530251584

# %%
### Plotting 
# shift train predictions for plotting
look_back=100
trainPredictPlot = numpy.empty_like(df1)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(df1)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df1)-1, :] = test_predict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(df1))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
len(test_data)
# Out:
# 696

# %%
x_input=test_data[341:].reshape(1,-1)
x_input.shape
# Out:
# (1, 355)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

# %%
temp_input
# Out:
# [0.6155253588878913,
#  0.6314689300297402,
#  0.6304234255318046,
#  0.6291166037175435,
#  0.6353893954725245,
#  0.6296393428980316,
#  0.6481965576684035,
#  0.668583359570484,
#  0.6610037198642822,
#  0.6596967935021847,
#  0.6589127108684114,
#  0.668322042254158,
#  0.6759017865081958,
#  0.6743335166928133,
#  0.6717198730642904,
#  0.67354943405904,
#  0.6680605942530369,
#  0.6688447814346461,
#  0.6531625537460821,
#  0.6474124750346302,
#  0.6487193229858508,
#  0.6291166037175435,
#  0.641923635228627,
#  0.62049135496557,
#  0.6191845331513086,
#  0.5940930524878754,
#  0.6035023838736218,
#  0.6082070364980154,
#  0.6118662107614328,
#  0.6327757518440016,
#  0.6272870165858346,
#  0.6427078224102365,
#  0.6421850832297482,
#  0.6432305877276836,
#  0.6055932883216564,
#  0.599059048565554,
#  0.5927862306736138,
#  0.5925248088094515,
#  0.5846837472390876,
#  0.5862519909175115,
#  0.5750130985370152,
#  0.6079456146338533,
#  0.607422875453365,
# ...

# %%
# demonstrate prediction for next 10 days
from numpy import array

lst_output=[]
n_steps=354
i=0
while(i<30):
    
    if(len(temp_input)>354):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        print(x_input.shape)
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1
    

print(lst_output)
# Out:
# 0 day input [0.63146893 0.63042343 0.6291166  0.6353894  0.62963934 0.64819656
#  0.66858336 0.66100372 0.65969679 0.65891271 0.66832204 0.67590179
#  0.67433352 0.67171987 0.67354943 0.66806059 0.66884478 0.65316255
#  0.64741248 0.64871932 0.6291166  0.64192364 0.62049135 0.61918453
#  0.59409305 0.60350238 0.60820704 0.61186621 0.63277575 0.62728702
#  0.64270782 0.64218508 0.64323059 0.60559329 0.59905905 0.59278623
#  0.59252481 0.58468375 0.58625199 0.5750131  0.60794561 0.60742288
#  0.60454778 0.60611605 0.61238895 0.61343435 0.61055939 0.62650283
#  0.62388919 0.6097752  0.64349191 0.6364349  0.64558291 0.6547308
#  0.7731312  0.77731311 0.8068479  0.80423423 0.79325665 0.79377942
#  0.78280195 0.76607419 0.73157343 0.74255101 0.76999479 0.76006272
#  0.75953995 0.76685838 0.79534766 0.78437009 0.77679034 0.76555156
#  0.76555156 0.76136954 0.74777842 0.73967591 0.76633564 0.76215373
#  0.74673292 0.75640357 0.74830106 0.74647147 0.73366444 0.72791426
# ...

# %%
day_new=np.arange(1,355)
day_pred=np.arange(355,385)

# %%
import matplotlib.pyplot as plt

# %%
len(df1)
# Out:
# 1988

# %%
plt.plot(day_new,scaler.inverse_transform(df1[1634:]))
plt.plot(day_pred,scaler.inverse_transform(lst_output))

# %%
df3=df1.tolist()
df3.extend(lst_output)
plt.plot(df3[354:])

# %%
df3=scaler.inverse_transform(df3).tolist()

# %%
plt.plot(df3)

# %%
url2="https://query1.finance.yahoo.com/v7/finance/download/MSFT?period1=1465603200&period2=1623369600&interval=1d&events=history&includeAdjustedClose=true"
data1 = pd.read_csv(url2)
print(data1)

# %%
data1.tail()

# %% [markdown]
# # NLP PART HEADLINES

# %%
df=pd.read_csv('Combined_News_DJIA.csv', encoding = "ISO-8859-1")

# %%
df
# Out:
#             Date  Label                                               Top1  \
# 0     2008-08-08      0  b"Georgia 'downs two Russian warplanes' as cou...
# 1     2008-08-11      1  b'Why wont America and Nato help us? If they w...
# 2     2008-08-12      0  b'Remember that adorable 9-year-old who sang a...
# 3     2008-08-13      0  b' U.S. refuses Israel weapons to attack Iran:...
# 4     2008-08-14      1  b'All the experts admit that we should legalis...
# ...          ...    ...                                                ...
# 1984  2016-06-27      0  Barclays and RBS shares suspended from trading...
# 1985  2016-06-28      1  2,500 Scientists To Australia: If You Want To ...
# 1986  2016-06-29      1                   Explosion At Airport In Istanbul
# 1987  2016-06-30      1  Jamaica proposes marijuana dispensers for tour...
# 1988  2016-07-01      1  A 117-year-old woman in Mexico City finally re...
#
#                                                    Top2  \
# ...

# %%
train = df[df['Date'] < '20150101']
test = df[df['Date'] > '20141231']

# %%
# Removing punctuations
data=train.iloc[:,2:27]
data.replace("[^a-zA-Z]"," ",regex=True, inplace=True)

# Renaming column names for ease of access
list1= [i for i in range(25)]
new_Index=[str(i) for i in list1]
data.columns= new_Index
data.head(5)
# Out:
#                                                    0  \
# 0  b Georgia  downs two Russian warplanes  as cou...
# 1  b Why wont America and Nato help us  If they w...
# 2  b Remember that adorable   year old who sang a...
# 3  b  U S  refuses Israel weapons to attack Iran ...
# 4  b All the experts admit that we should legalis...
#
#                                                    1  \
# 0            b BREAKING  Musharraf to be impeached
# 1        b Bush puts foot down on Georgian conflict
# 2                 b Russia  ends Georgia operation
# 3  b When the president ordered to attack Tskhinv...
# 4  b War in South Osetia      pictures made by a ...
#
#                                                    2  \
# 0  b Russia Today  Columns of troops roll into So...
# 1  b Jewish Georgian minister  Thanks to Israeli ...
# 2  b  If we had no sexual harassment we would hav...
# 3  b  Israel clears troops who killed Reuters cam...
# 4  b Swedish wrestler Ara Abrahamian throws away ...
#
# ...

# %%
# Convertng headlines to lower case
for index in new_Index:
    data[index]=data[index].str.lower()
data.head(1)
# Out:
#                                                    0  \
# 0  b georgia  downs two russian warplanes  as cou...
#
#                                          1  \
# 0  b breaking  musharraf to be impeached
#
#                                                    2  \
# 0  b russia today  columns of troops roll into so...
#
#                                                    3  \
# 0  b russian tanks are moving towards the capital...
#
#                                                    4  \
# 0  b afghan children raped with  impunity   u n  ...
#
#                                                    5  \
# 0  b     russian tanks have entered south ossetia...
#
#                                                    6  \
# 0  b breaking  georgia invades south ossetia  rus...
#
#                                                    7  \
# 0  b the  enemy combatent  trials are nothing but...
#
#                                                    8  \
# ...

# %%
' '.join(str(x) for x in data.iloc[1,0:25])
# Out:
# 'b why wont america and nato help us  if they wont help us now  why did we help them in iraq   b bush puts foot down on georgian conflict  b jewish georgian minister  thanks to israeli training  we re fending off russia   b georgian army flees in disarray as russians advance   gori abandoned to russia without a shot fired  b olympic opening ceremony fireworks  faked   b what were the mossad with fraudulent new zealand passports doing in iraq   b russia angered by israeli military sale to georgia  b an american citizen living in s ossetia blames u s  and georgian leaders for the genocide of innocent people  b welcome to world war iv  now in high definition   b georgia s move  a mistake of monumental proportions   b russia presses deeper into georgia  u s  says regime change is goal  b abhinav bindra wins first ever individual olympic gold medal for india  b  u s  ship heads for arctic to define territory  b drivers in a jerusalem taxi station threaten to quit rather than work for thei
# ...

# %%
headlines = []
for row in range(0,len(data.index)):
    headlines.append(' '.join(str(x) for x in data.iloc[row,0:25]))

# %%
headlines[0]
# Out:
# 'b georgia  downs two russian warplanes  as countries move to brink of war  b breaking  musharraf to be impeached   b russia today  columns of troops roll into south ossetia  footage from fighting  youtube   b russian tanks are moving towards the capital of south ossetia  which has reportedly been completely destroyed by georgian artillery fire  b afghan children raped with  impunity   u n  official says   this is sick  a three year old was raped and they do nothing  b     russian tanks have entered south ossetia whilst georgia shoots down two russian jets   b breaking  georgia invades south ossetia  russia warned it would intervene on so s side  b the  enemy combatent  trials are nothing but a sham  salim haman has been sentenced to       years  but will be kept longer anyway just because they feel like it   b georgian troops retreat from s  osettain capital  presumably leaving several hundred people killed   video   b did the u s  prep georgia for war with russia   b rice gives gre
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier

# %%
## implement BAG OF WORDS
countvector=CountVectorizer(ngram_range=(2,2))
traindataset=countvector.fit_transform(headlines)

# %%
# implement RandomForest Classifier
randomclassifier=RandomForestClassifier(n_estimators=200,criterion='entropy')
randomclassifier.fit(traindataset,train['Label'])
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=200)

# %%
## Predict for the Test Dataset
test_transform= []
for row in range(0,len(test.index)):
    test_transform.append(' '.join(str(x) for x in test.iloc[row,2:27]))
test_dataset = countvector.transform(test_transform)
predictions = randomclassifier.predict(test_dataset)

# %%
## Import library to check accuracy
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
matrix=confusion_matrix(test['Label'],predictions)
print(matrix)
score=accuracy_score(test['Label'],predictions)
print(score)
report=classification_report(test['Label'],predictions)
print(report)
# Out:
# [[131  55]
#  [  0 192]]
# 0.8544973544973545
#               precision    recall  f1-score   support
#
#            0       1.00      0.70      0.83       186
#            1       0.78      1.00      0.87       192
#
#     accuracy                           0.85       378
#    macro avg       0.89      0.85      0.85       378
# weighted avg       0.89      0.85      0.85       378

# %%
df.shape
# Out:
# (1989, 27)

# %%
import pandas as pd
import csv
# reading two csv files
data1 = pd.read_csv('Combined_News_DJIA_1.csv',encoding = "ISO-8859-1")
data1 = data1[['Date','Label']]

# %%
print(data1)
# Out:
#             Date  Label
# 0     08-08-2008      0
# 1     11-08-2008      1
# 2     12-08-2008      0
# 3     13-08-2008      0
# 4     14-08-2008      1
# ...          ...    ...
# 1984  27-06-2016      0
# 1985  28-06-2016      1
# 1986  29-06-2016      1
# 1987  30-06-2016      1
# 1988  01-07-2016      1
#
# [1989 rows x 2 columns]

# %%
import copy
temp=data1['Date']
#print(temp)
for i in range(len(temp)):
    ls=[temp[i].split('-')]
    #print(ls[0])
    year=ls[0][0]
    month=ls[0][1]
    day=ls[0][2]
    string=day+"-"+month+"-"+year
    #print(string)
    temp[i]=copy.copy(string)
    #print(temp[i])
    
#print(temp)
data1['Date']=copy.copy(temp)
print(data1['Date'])
# Out:
# <ipython-input-78-a0cddbabd82d>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp[i]=copy.copy(string)
# 0       2008-08-08
# 1       2008-08-11
# 2       2008-08-12
# 3       2008-08-13
# 4       2008-08-14
#            ...
# 1984    2016-06-27
# 1985    2016-06-28
# 1986    2016-06-29
# 1987    2016-06-30
# 1988    2016-07-01
# Name: Date, Length: 1989, dtype: object

# %%
url = "https://query1.finance.yahoo.com/v7/finance/download/MSFT?period1=1218153600&period2=1467331200&interval=1d&events=history&includeAdjustedClose=true"
data2 = pd.read_csv(url)

# %%
print(data1,data2)
# Out:
#             Date  Label
# 0     2008-08-08      0
# 1     2008-08-11      1
# 2     2008-08-12      0
# 3     2008-08-13      0
# 4     2008-08-14      1
# ...          ...    ...
# 1984  2016-06-27      0
# 1985  2016-06-28      1
# 1986  2016-06-29      1
# 1987  2016-06-30      1
# 1988  2016-07-01      1
#
# [1989 rows x 2 columns]             Date       Open       High        Low      Close  Adj Close  \
# 0     2008-08-08  27.350000  28.230000  27.190001  28.129999  21.081116
# 1     2008-08-11  27.860001  28.400000  27.660000  27.900000  20.908747
# 2     2008-08-12  27.780001  28.360001  27.580000  28.120001  21.073622
# 3     2008-08-13  28.070000  28.500000  27.760000  27.910000  20.916243
# 4     2008-08-14  27.820000  28.280001  27.559999  27.910000  20.916243
# ...          ...        ...        ...        ...        ...        ...
# 1983  2016-06-24  49.810001  50.939999  49.520000  49.830002  45.906292
# ...

# %%
#data2 = pd.read_csv(data)

# using merge function by setting how='inner'
output1 = pd.merge(data2, data1, on='Date', how='inner')
  
# displaying result
print(output1)
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2008-08-08  27.350000  28.230000  27.190001  28.129999  21.081116
# 1     2008-08-11  27.860001  28.400000  27.660000  27.900000  20.908747
# 2     2008-08-12  27.780001  28.360001  27.580000  28.120001  21.073622
# 3     2008-08-13  28.070000  28.500000  27.760000  27.910000  20.916243
# 4     2008-08-14  27.820000  28.280001  27.559999  27.910000  20.916243
# ...          ...        ...        ...        ...        ...        ...
# 1983  2016-06-24  49.810001  50.939999  49.520000  49.830002  45.906292
# 1984  2016-06-27  49.099998  49.150002  48.040001  48.430000  44.616528
# 1985  2016-06-28  48.919998  49.470001  48.669998  49.439999  45.546997
# 1986  2016-06-29  49.910000  50.720001  49.799999  50.540001  46.560383
# 1987  2016-06-30  50.720001  51.299999  50.500000  51.169998  47.140781
#
#          Volume  Label
# 0      80814100      0
# 1      68743800      1
# 2      62813000      0
# ...

# %%
output1.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2008-08-08  27.350000  28.230000  27.190001  28.129999  21.081116
# 1  2008-08-11  27.860001  28.400000  27.660000  27.900000  20.908747
# 2  2008-08-12  27.780001  28.360001  27.580000  28.120001  21.073622
# 3  2008-08-13  28.070000  28.500000  27.760000  27.910000  20.916243
# 4  2008-08-14  27.820000  28.280001  27.559999  27.910000  20.916243
#
#      Volume  Label
# 0  80814100      0
# 1  68743800      1
# 2  62813000      0
# 3  51165200      0
# 4  49732300      1

# %%
output1.describe()
data=output1

# %%
data.rename(columns = {'Adj Close' : 'Adj_Close'}, inplace = True)
data.describe()
data['Open'] = data['Open'].fillna(0)
data['High'] = data['High'].fillna(0)
data['Low'] = data['Low'].fillna(0)
data['Close'] = data['Close'].fillna(0)
data['Adj_Close'] = data['Adj_Close'].fillna(0)
data['Volume'] = data['Volume'].fillna(0)
data['Label'] = data['Label'].fillna(0)

# %%
data[:1]
# Out:
#          Date   Open   High        Low      Close  Adj_Close    Volume  Label
# 0  2008-08-08  27.35  28.23  27.190001  28.129999  21.081116  80814100      0

# %%
'''
import numpy as np
for i in range(len(data.Volume)):
    if (data.Volume)[i]<=np.percentile(data.Volume,[1.8])[0]:
        print((data.Volume)[i])
        data.Volume[i] = data.Volume[i-1]
        
    if (data.Open)[i]<=np.percentile(data.Open,[1.8])[0]:
        print((data.Open)[i])
        data.Open[i] = data.Open[i-1]
        
    if (data.High)[i]<=np.percentile(data.High,[1.8])[0]:
        print((data.High)[i])
        data.High[i] = data.High[i-1]
        
    if (data.Low)[i]<=np.percentile(data.Low,[1.8])[0]:
        print((data.Low)[i])
        data.Low[i] = data.Low[i-1]
        
    if (data.Close)[i]<=np.percentile(data.Close,[1.8])[0]:
        print((data.Close)[i])
        data.Close[i] = data.Close[i-1]
        
    if (data.Adj_Close)[i]<=np.percentile(data.Adj_Close,[1.8])[0]:
        print((data.Adj_Close)[i])
        data.Adj_Close[i] = data.Adj_Close[i-1]
        
    if (data.Label)[i]<=np.percentile(data.Label,[1.8])[0]:
        print((data.Label)[i])
        data.Label[i] = data.Label[i-1]
        
'''
# Out:
# '\nimport numpy as np\nfor i in range(len(data.Volume)):\n    if (data.Volume)[i]<=np.percentile(data.Volume,[1.8])[0]:\n        print((data.Volume)[i])\n        data.Volume[i] = data.Volume[i-1]\n        \n    if (data.Open)[i]<=np.percentile(data.Open,[1.8])[0]:\n        print((data.Open)[i])\n        data.Open[i] = data.Open[i-1]\n        \n    if (data.High)[i]<=np.percentile(data.High,[1.8])[0]:\n        print((data.High)[i])\n        data.High[i] = data.High[i-1]\n        \n    if (data.Low)[i]<=np.percentile(data.Low,[1.8])[0]:\n        print((data.Low)[i])\n        data.Low[i] = data.Low[i-1]\n        \n    if (data.Close)[i]<=np.percentile(data.Close,[1.8])[0]:\n        print((data.Close)[i])\n        data.Close[i] = data.Close[i-1]\n        \n    if (data.Adj_Close)[i]<=np.percentile(data.Adj_Close,[1.8])[0]:\n        print((data.Adj_Close)[i])\n        data.Adj_Close[i] = data.Adj_Close[i-1]\n        \n    if (data.Label)[i]<=np.percentile(data.Label,[1.8])[0]:\n        pr
# ...

# %%
df1=data.reset_index()['Close']
df1[:60]
# Out:
# 0     28.129999
# 1     27.900000
# 2     28.120001
# 3     27.910000
# 4     27.910000
# 5     27.809999
# 6     27.690001
# 7     27.320000
# 8     27.290001
# 9     27.180000
# 10    27.840000
# 11    27.660000
# 12    27.270000
# 13    27.559999
# 14    27.940001
# 15    27.290001
# 16    27.100000
# 17    26.900000
# 18    26.350000
# 19    25.650000
# 20    26.120001
# 21    26.100000
# 22    26.440001
# 23    27.340000
# 24    27.620001
# 25    26.820000
# 26    25.990000
# 27    24.570000
# 28    25.260000
# 29    25.160000
# 30    25.400000
# 31    25.440001
# 32    25.719999
# 33    26.610001
# 34    27.400000
# 35    25.010000
# 36    26.690001
# 37    26.480000
# 38    26.250000
# 39    26.320000
# 40    24.910000
# 41    23.230000
# 42    23.010000
# 43    22.299999
# 44    21.500000
# 45    25.500000
# 46    24.100000
# 47    22.660000
# 48    24.190001
# 49    23.930000
# 50    24.719999
# 51    23.360001
# 52    21.530001
# 53    22.320000
# 54    21.959999
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(df1)

# %%
from pandas_datareader import data
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
import urllib.request, json
import os
import numpy as np
import tensorflow as tf # This code has been tested with TensorFlow 1.6
from sklearn.preprocessing import MinMaxScaler

# %%
df1.shape
# Out:
# (1988,)

# %%
scaler = MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
df1.shape
# Out:
# (1988, 1)

# %%
training_size=int(len(df1)*0.65)
test_size=len(df1)-training_size
train_data,test_data=df1[0:training_size,:],df1[training_size:len(df1),:1]

# %%
training_size,test_size
# Out:
# (1292, 696)

# %%
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (1191, 100)
# (1191,)
# (None, None)

# %%
print(X_test.shape), print(ytest.shape)
# Out:
# (595, 100)
# (595,)
# (None, None)

# %%
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
### Create the Stacked LSTM model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(units=50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(units=50,return_sequences=True))
model.add(LSTM(units=50))
model.add(Dense(units=1))
model.compile(optimizer='adam',loss='mean_squared_error')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm (LSTM)                  (None, 100, 50)           10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100, 50)           20200
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# ...
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 19/19 [==============================] - 9s 209ms/step - loss: 0.0338 - val_loss: 0.0484
# Epoch 2/100
# 19/19 [==============================] - 2s 122ms/step - loss: 0.0022 - val_loss: 0.0310
# Epoch 3/100
# 19/19 [==============================] - 3s 159ms/step - loss: 0.0013 - val_loss: 0.0091
# Epoch 4/100
# 19/19 [==============================] - 3s 161ms/step - loss: 7.6816e-04 - val_loss: 0.0026
# Epoch 5/100
# 19/19 [==============================] - 2s 117ms/step - loss: 6.6975e-04 - val_loss: 0.0019
# Epoch 6/100
# 19/19 [==============================] - 2s 122ms/step - loss: 7.0168e-04 - val_loss: 0.0023
# Epoch 7/100
# 19/19 [==============================] - 2s 121ms/step - loss: 6.8394e-04 - val_loss: 0.0018
# Epoch 8/100
# 19/19 [==============================] - 2s 110ms/step - loss: 6.3001e-04 - val_loss: 0.0018
# Epoch 9/100
# 19/19 [==============================] - 3s 138ms/step - loss: 6.3336e-04 - val_loss: 0.0021
# Epoch 10/100
# ...

# %%
import tensorflow as tf

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# %%
##Transformback to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
len(train_predict),len(test_predict),len(y_train),len(ytest)
# Out:
# (1191, 595, 1191, 595)

# %%
train_predict
# Out:
# array([[19.204336],
#        [19.304228],
#        [19.651697],
#        ...,
#        [33.393494],
#        [32.9923  ],
#        [32.62377 ]], dtype=float32)

# %%
### Calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 27.129665328245075

# %%
### Test Data RMSE
math.sqrt(mean_squared_error(ytest,test_predict))
# Out:
# 45.85229060709989

# %%
### Plotting 
# shift train predictions for plotting
look_back=100
trainPredictPlot = numpy.empty_like(df1)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(df1)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df1)-1, :] = test_predict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(df1))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
len(test_data)
# Out:
# 696

# %%
x_input=test_data[341:].reshape(1,-1)
x_input.shape
# Out:
# (1, 355)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

# %%
# demonstrate prediction for next 10 days
from numpy import array

lst_output=[]
n_steps=354
i=0
while(i<30):
    
    if(len(temp_input)>354):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        print(x_input.shape)
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1
    

print(lst_output)
# Out:
# 0 day input [0.65942033 0.65845412 0.65724642 0.66304345 0.65772951 0.67487924
#  0.6937198  0.68671504 0.68550724 0.68478263 0.6934783  0.70048316
#  0.69903383 0.69661842 0.69830922 0.69323668 0.69396139 0.67946859
#  0.67415463 0.67536236 0.65724642 0.66908209 0.64927535 0.64806765
#  0.62487924 0.63357492 0.63792274 0.64130439 0.66062804 0.6555556
#  0.6698068  0.66932371 0.67028992 0.63550724 0.62946859 0.62367154
#  0.62342994 0.61618359 0.61763289 0.60724642 0.63768115 0.63719806
#  0.63454103 0.63599035 0.64178748 0.64275359 0.64009668 0.65483089
#  0.65241547 0.63937197 0.67053142 0.66400965 0.67246383 0.68091789
#  0.79033816 0.79420289 0.8214976  0.81908217 0.80893719 0.80942031
#  0.79927543 0.7838164  0.75193236 0.76207734 0.78743963 0.77826086
#  0.77777775 0.78454111 0.81086961 0.80072463 0.79371978 0.7833334
#  0.7833334  0.77946857 0.76690828 0.75942031 0.78405801 0.78019328
#  0.76594207 0.77487925 0.76739127 0.76570045 0.75386478 0.74855072
# ...

# %%
day_new=np.arange(1,355)
day_pred=np.arange(355,385)

# %%
import matplotlib.pyplot as plt

# %%
len(df1)
# Out:
# 1988

# %%
plt.plot(day_new,scaler.inverse_transform(df1[1634:]))
plt.plot(day_pred,scaler.inverse_transform(lst_output))

# %%
df3=df1.tolist()
df3.extend(lst_output)
plt.plot(df3[354:])

# %%
df3=scaler.inverse_transform(df3).tolist()

# %%
plt.plot(df3)
